# %% [markdown]
# <a href="https://colab.research.google.com/github/nicholaschincu/Python-Project/blob/main/CS102_Python_MiniProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #for data manipulation
import numpy as np #for numerical computation
import matplotlib.pyplot as plt #for plotting and visualiazations
import seaborn as sns #for plotting and visualiazations
import plotly.express as px #for plotting and visualiazations
from plotly.subplots import make_subplots #for plotting and visualiazations
from datetime import datetime #for plotting and visualiazations

covid_df=pd.read_csv("https://api.covid19india.org/csv/latest/case_time_series.csv")

# %%
covid_df.head(1000) #to see an x number of rows of data
# Out:
#     date_of_interest  CASE_COUNT  ...  SI_ALL_DEATH_COUNT_7DAY_AVG  INCOMPLETE
# 0         02/29/2020           1  ...                            0           0
# 1         03/01/2020           0  ...                            0           0
# 2         03/02/2020           0  ...                            0           0
# 3         03/03/2020           1  ...                            0           0
# 4         03/04/2020           5  ...                            0           0
# ..               ...         ...  ...                          ...         ...
# 649       12/09/2021        2906  ...                            1       11000
# 650       12/10/2021        2935  ...                            0       11000
# 651       12/11/2021        1912  ...                            0       11000
# 652       12/12/2021        2265  ...                            0       11000
# 653       12/13/2021        4477  ...                            1       11000
#
# [654 rows x 67 columns]

# %%
covid_df.describe #for numerical analysis
# Out:
# <bound method NDFrame.describe of                 Date    Date_YMD  ...  Daily Deceased  Total Deceased
# 0    30 January 2020  2020-01-30  ...               0               0
# 1    31 January 2020  2020-01-31  ...               0               0
# 2    1 February 2020  2020-02-01  ...               0               0
# 3    2 February 2020  2020-02-02  ...               0               0
# 4    3 February 2020  2020-02-03  ...               0               0
# ..               ...         ...  ...             ...             ...
# 636  27 October 2021  2021-10-27  ...             734          455828
# 637  28 October 2021  2021-10-28  ...             805          456633
# 638  29 October 2021  2021-10-29  ...             551          457184
# 639  30 October 2021  2021-10-30  ...             445          457629
# 640  31 October 2021  2021-10-31  ...             251          457880
#
# [641 rows x 8 columns]>

# %%
#Growth Trend

data = pd.read_csv("https://api.covid19india.org/csv/latest/case_time_series.csv")

Y = data.iloc[100:,2].values #Stores Daily Confirmed
R = data.iloc[100:,4].values #Stores Daily Recovered
D = data.iloc[100:,7].values #Stores Daily Deceased

X = data.iloc[100:,0] #Stores Date

Y = data.iloc[100:,2].values 
R = data.iloc[100:,4].values 
D = data.iloc[100:,7].values 
X = data.iloc[100:,0] 
  
plt.plot(X,Y)

plt.figure(figsize=(100,10))

ax = plt.axes()
ax.grid(linewidth=0.5, color='#8f8f8f') 
  
ax.set_facecolor("black") 
ax.set_xlabel('\nDate',size=30,color='#4bb4f2')
ax.set_ylabel('Number of Confirmed Cases\n',
              size=30,color='#4bb4f2')
  
ax.plot(X,Y,
        color='#1F77B4',
        marker='o',
        linewidth=10,
        markersize=10,
        markeredgecolor='#035E9B')
